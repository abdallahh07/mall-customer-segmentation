# %% [markdown]
# <div style = "background-color:#1F3864; padding:25px; border-radius:8px;">
# <h1 style="color:white; text-align:center; margin:0;"> Mall Customer Segmentation </h1>
# <p style="color:#D9E2F3; text-align:center; margin-top:10px; font-size:15px;">
# segmenting mall customers by annual income and spending score to identify target customer groups for marketing.
# </p>
# </div>

# %% [markdown]
# # Mall Customer Segmentation
#
# K-Means clustering practice — segmenting mall customers by annual income and spending score to identify target customer groups for marketing.
#
# ## Overview
#
# This is a hands-on practice project — my first time building a clustering model. Using the classic Mall Customers dataset (200 customers, membership card data), the goal is to segment customers into distinct groups a marketing team could target differently.
#
# **What this notebook covers:**
# 1. Load and explore the data
# 2. Select and scale relevant features (Annual Income, Spending Score)
# 3. Use the elbow method to choose the number of clusters
# 4. Fit K-Means and visualize the resulting segments
# 5. Interpret what each customer segment represents
#
# **Dataset**: [Mall Customer Segmentation Data](https://www.kaggle.com/datasets/vjchoudhary7/customer-segmentation-tutorial-in-python) — CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100)

# %% [markdown]
# <div style="background-color:#EDCC80; padding:15px; border-radius:8px;">
# <h2 style="color:#1F3864; text-align:center; margin:0;">1. Load the Data</h2>
# </div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/Mall_Customers.csv")

# %% [markdown]
# <div style="background-color:#EDCC80; padding:15px; border-radius:8px;">
# <h2 style="color:#1F3864; text-align:center; margin:0;">2. Review the Data</h2>
# </div>

# %% [markdown]
# <div style="background-color:#EDEAE5; padding:10px 15px; border-radius:6px;">
# <h3 style="color:#1F3864; text-align:center; margin:0;">2.1 Checking the data types</h3>
# </div>

# %%
data.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# <div style="background-color:#EDCC80; padding:15px; border-radius:8px;">
# <h2 style="color:#1F3864; text-align:center; margin:0;">3. Explanatory Data Analysis (EDA)</h2>
# </div>

# %% [markdown]
# <div style="background-color:#EDEAE5; padding:10px 15px; border-radius:6px;">
# <h3 style="color:#1F3864; text-align:center; margin:0;">3.1 Statistical Analysis</h3>
# </div>

# %%
f = data.select_dtypes(include="number").columns.tolist()

# %%
fig,ax = plt.subplots(4,1,figsize=(12,12))
ax = ax.flatten()
for i,name in enumerate(f):
    data[name].hist(ax = ax[i])
    
    ax[i].set_title(name)

plt.tight_layout()

# %% [markdown]
# <div style="background-color:#EDCC80; padding:15px; border-radius:8px;">
# <h2 style="color:#1F3864; text-align:center; margin:0;">4. Data Preprocessing</h2>
# </div>

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
data = data.drop(columns=["CustomerID"])

# %%
x = data[["Annual Income (k$)", "Spending Score (1-100)"]]

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(X)
